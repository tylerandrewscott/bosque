# %%
# Out:
# ['ACRES HOMES ID', 'ADDICKS UTILITY DISTRICT']

# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

empty_dww = pd.DataFrame()
empty_district_info = pd.DataFrame()
empty_audit_info = pd.DataFrame()
driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
base_page = 'http://www14.tceq.texas.gov/iwud/dist/index.cfm?fuseaction=ListDistricts&COMMAND=LIST&compress=N&StartName=&ID=&RegionCode=&DistTypeCode=&CreationTypeCode=&DistFunctionTypeCode=&CountyCode=&FinancialStatus=&ActivityStatus=&ListStart='
driver.get(base_page)
#CountyCode

houston_counties = [79,101,170]

from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
#
# select by value 
#select.select_by_value('1')
#wait = WebDriverWait(driver, 10)
select = Select(driver.find_element_by_css_selector('#CountyCode'))
wd_info_call = '.iwuddata:nth-child(2)'
#wd_info_header = 'tr:nth-child(5) .iwudheading , .iwudheading:nth-child(1)'
wd_info_header = '.iwudheading:nth-child(1)'
#for county in houston_counties:
count = 0
select_county = Select(driver.find_element_by_css_selector('#CountyCode'))
select_county.select_by_value(str(101))
driver.find_elements_by_css_selector('input')[1].click()
css_find_wds = "table+ table .iwud a"
css_find_number = '.iwud+ .iwud:nth-child(3)'
css_find_status = '.iwud~ .iwud+ .iwud'
css_to_click_more = "table+ table tr:nth-child(1) a:nth-child(1) img"
audit_vars_css = 'td.iwud:nth-child(1)'
audit_vals_css = '.iwud+ td'
get_doc_id = 'table:nth-child(6) tr:nth-child(1) .iwuddata'

System = [];Status = []; ID = []
#### Grab basic district info
count = 0

for system in range(2000):
    print('system' + str(system))
    temp_wd = driver.find_elements_by_css_selector(css_find_wds)
    temp_status = driver.find_elements_by_css_selector(css_find_status)
    temp_number = driver.find_elements_by_css_selector(css_find_number)
    System.append(temp_wd[count].text)
    Status.append(temp_status[count].text)
    ID.append(temp_number[count].text)
    water_systems = driver.find_elements_by_css_selector(css_find_wds)
    #for systems in range(len(water_systems)):
    temp_name = driver.find_elements_by_css_selector(css_find_wds)[count].text
    print(temp_name)
    temp_id = driver.find_elements_by_css_selector(css_find_number)[count].text
    driver.find_elements_by_css_selector(css_find_wds)[count].click()
    info_vars = []
    info = []
    for el in driver.find_elements_by_css_selector(wd_info_call):
        info.append(el.text)
    for el in driver.find_elements_by_css_selector(wd_info_header):
        info_vars.append(el.text)
    i = 0
    for v in range(len(info_vars)):
        if info_vars[v] == '':
            i = i + 1
            info_vars[v] = str(i)
            #print(info_vars);print(info)
    temp = pd.DataFrame(info).T
    temp.columns = [info_vars]
    temp['NAME'] = temp_name
    temp['WDD_ID'] = temp_id
    #for dup in range(sum(temp.columns.duplicated())):
    while sum(temp.columns.duplicated())>0:
        temp = temp.drop(temp.columns[temp.columns.duplicated()][0],axis=1)
        #temp = temp.drop('Address:', axis=1)
        #temp = temp.columns.drop_duplicates()
        #print(temp_info)
        #if empty_dww.shape[0] !=0 & any(empty_dww['Name'] == temp_name):
        #    driver.back()
        #    continue  join(temp_info,how='outer')
        #print(temp.columns)
    empty_district_info = pd.concat([empty_district_info,temp], axis=0, join='outer', ignore_index=True)
    empty_district_info.to_csv('../Input/tceq_audits/harris_system_info.csv')
        #empty_district_info = empty_district_info.append(temp,how='outer')
        #empty_district_info =  = empty_district_info.append(temp)
        #grouped = empty_district_info.groupby(level=0)
        #empty_district_info = grouped.last()
    driver.find_element_by_css_selector('.iwud a+ a img').click()
        #doc_list = driver.find_elements_by_css_selector('.iwudcolor+ tr td')
    audit_links = driver.find_elements_by_partial_link_text('AUDIT')
    if (len(audit_links)==0):
        driver.back()
    if (len(audit_links)!=0):
        for audit in range(len(audit_links)):
            audit_links = driver.find_elements_by_partial_link_text('AUDIT')
            doc_link = audit_links[audit].get_attribute('href')
            audit_links[audit].click()   
            avars = []; avals = []
            doc_id = driver.find_element_by_css_selector(get_doc_id).text
            #print('docid')
            #print(doc_id)
            for var in driver.find_elements_by_css_selector(audit_vars_css):
                avars.append(var.text)
            for var in driver.find_elements_by_css_selector(audit_vals_css):
                avals.append(var.text)
            temp_audit = pd.DataFrame(avals).T
            temp_audit.columns = avars
            temp_audit['DOC_ID'] = doc_id
            temp_audit['SYSTEM_NAME'] = temp_name
            temp_audit['SYSTEM_ID'] = temp_id
            temp_audit['DOC_LINK'] = doc_link
                #temp_audit,index=avars,columns = [doc_id])
                #temp_audit = temp_audit.append(pd.DataFrame([id],index=['System ID'],columns=[doc_id]))
                #temp_audit = temp_audit.append(pd.DataFrame([doc_link],index=['Doc_Link'],columns=[doc_id]))
            empty_audit_info = pd.concat([empty_audit_info,temp_audit],axis=0, join='outer', ignore_index=True)
            empty_audit_info.to_csv('../Input/tceq_audits/harris_audits.csv')
            driver.back()
        driver.back()
    driver.back()
    if len(temp_wd)<49 & count == len(temp_wd):
        break
    if count == 49:
        driver.find_element_by_css_selector(css_to_click_more).click()
        count = 0
        continue
    count = count + 1
system_list_df = pd.DataFrame({'Name': System, 'Status': Status,'ID': ID,'County': 'HARRIS'})
#empty_dww = empty_dww.append(system_list_df)       
#harris_dww = system_list_df
system_list_df.to_csv('../Input/tceq_audits/harris_base.csv')
#harris_audits = empty_audit_info
#harris_systems = empty_district_info


#while len(driver.find_element_by_css_selector(css_to_click_more))>0:
#    driver.find_element_by_css_selector(css_to_click_more).click()
# Out:
# system0
# ACRES HOMES ID
# system1
# ADDICKS UTILITY DISTRICT
# system2
# AIRLINE IMPROVEMENT DISTRICT
# system3
# ALDINE MUD
# system4
# ALDINE MUD 1
# system5
# ALDINE PUD
# system6
# ARCADIAN GARDENS MUD
# system7
# BAKER ROAD MUD
# system8
# BAMMEL UTILITY DISTRICT
# system9
# BAMMEL UTILITY DISTRICT
# system10
# BARKER CYPRESS MUD
# system11
# BARRETT MANAGEMENT DISTRICT
# system12
# BAUER LANDING WCID
# system13
# BAYBROOK MANAGEMENT DISTRICT
# system14
# BAYBROOK MUD 1
# system15
# BAYFIELD PUD
# system16
# BAYSHORE MUD
# system17
# BAYTOWN AREA WATER AUTHORITY
# system18
# BEAR CREEK MUD
# system19
# BEAUMONT PLACE UTILITY DISTRICT
# system20
# BEECHNUT MUD
# system21
# BELTWAY 8 MUD 1
# system22
# BELTWAY 8 MUD 2
# system23
# BELTWAY 8 MUD 3
# system24
# BELTWAY MUD
# system25
# BILMA PUD
# system26
# BISSONNET MUD
# system27
# BOONE ROAD UTILITY DISTRICT
# system28
# BRAES UTILITY DISTRICT
# system29
# BRAZORIA COUNTY MUD 23
# system30
# BRIAR RIDGE MUD
# system31
# BRIARWICK IMPROVEMENT DISTRICT
# system32
# BRIDGELAND MANAGEMENT DISTRICT
# system33
# BRIDGESTONE MUD
# system34
# BROOKFIELD MUD
# system35
# BUFFALO BAYOU MANAGEMENT DISTRICT
# system36
# CAMFIELD MUD
# system37
# CANDLEWOOD MUD
# system38
# CARPENTERS BAYOU MUD
# system39
# CASTLEWOOD MUD
# system40
# CEDAR BAYOU PARK UTLITY DISTRICT
# system41
# CENTRAL HARRIS COUNTY REGIONAL WATER AUTHORITY
# system42
# CHAMPIONS MUNICIPAL UTILITY DISTRICT
# system43
# CHAPARRAL MUD
# system44
# CHARTERWOOD MUD
# system45
# CHELFORD CITY MUD
# system46
# CHELFORD ONE MUD
# system47
# CHIMNEY HILL MUD
# system48
# CIMARRON MUD
# system49
# CINCO MUD 3
# system50
# CINCO MUD 5
# system51
# CINCO MUD 6
# system52
# CINCO MUD 9
# system53
# CLAY ROAD MUD
# system54
# CLEAR BROOK CITY MUD
# system55
# CLEAR CREEK WATERSHED REGIONAL FLOOD CONTROL DISTRICT
# system56
# CLEAR LAKE CITY WATER AUTHORITY
# system57
# CLEAR WOODS IMPROVEMENT DISTRICT
# system58
# CNP UTILITY DISTRICT
# system59
# CNP UTILITY DISTRICT
# system60
# COASTAL WATER AUTHORITY
# system61
# CORNERSTONES MUD
# system62
# CROSBY MUD
# system63
# CY CHAMP PUD
# system64
# CY FAIR COMMUNITY IMPROVEMENT DISTRICT
# system65
# CYPRESS CREEK UTILITY DISTRICT
# system66
# CYPRESS CREEK UTILITY DISTRICT
# system67
# CYPRESS FOREST PUD
# system68
# CYPRESS HILL MUD 1
# system69
# CYPRESS HILL MUD 2
# system70
# CYPRESS KLEIN UTILITY DISTRICT
# system71
# CYPRESSWOOD UTILITY DISTRICT
# system72
# DEER MUD
# system73
# DOVE MEADOWS MUD
# system74
# DOWDELL PUD
# system75
# EAST ALDINE MANAGEMENT DISTRICT
# system76
# EAST DOWNTOWN MGMT DISTRICT
# system77
# EAST MONTROSE MANAGEMENT DISTRICT
# system78
# EL DORADO UTILITY DISTRICT
# system79
# EMERALD FOREST UTILITY DISTRICT
# system80
# ENCANTO REAL UTILITY DISTRICT
# system81
# ENCHANTED PLACE PUD
# system82
# ENCHANTED VALLEY PUD
# system83
# ENERGY CORRIDOR MANAGEMENT DISTRICT
# system84
# FAIRWOOD UTILITY DISTRICT
# system85
# FALL CREEK MANAGEMENT DISTRICT
# system86
# FALLBROOK UTILITY DISTRICT
# system87
# FAULKEY GULLY MUD
# system88
# FIVE CORNERS IMPROVEMENT DISTRICT
# system89
# FM 2920 BECKER ROAD MUD OF HARRIS COUNTY
# system90
# FONDREN LAKE MUD
# system91
# FOREST COVE ESTATES MUD
# system92
# FOREST COVE ESTATES MUD
# system93
# FOREST COVE MUD
# system94
# FOREST COVE MUD
# system95
# FOREST COVE MUD
# system96
# FOREST COVE MUD
# system97
# FOREST HILLS MUD
# system98
# FOREST POINT MUD
# system99
# FORESTS EDGE MUD
# system100
# FORT BEND COUNTY MUD 184
# system101
# FORT BEND COUNTY WCID 2
# system102
# FOUNTAINHEAD MUD
# system103
# FRY ROAD MUD
# system104
# GENERATION PARK MANAGEMENT DISTRICT
# system105
# GLEN HOLLOW PUD
# system106
# GLENSHIRE MUD
# system107
# GLENSHIRE MUD
# system108
# GRAND NORTHWEST MUD
# system109
# GRANT ROAD PUD
# system110
# GREATER EAST END MGMT DISTRICT
# system111
# GREATER NORTHSIDE MANAGEMENT DISTRICT
# system112
# GREATER SOUTHEAST MANAGEMENT DISTRICT
# system113
# GREATER WESTCHASE DISTRICT
# system114
# GREEN TRAILS MUD
# system115
# GREENBRIAR UTILITY DISTRICT
# system116
# GREENBRIAR UTILITY DISTRICT
# system117
# GREENS PARKWAY MUD
# system118
# GREENS PUD
# system119
# GREENWOOD UTILITY DISTRICT
# system120
# GREENWOOD UTILITY DISTRICT
# system121
# GULF COAST WASTE DISPOSAL AUTHORITY
# system122
# GULFTON AREA MUNICIPAL MANAGEMENT DISTRICT
# system123
# GULFWAY UTILITY DISTRICT
# system124
# GULFWAY UTILITY DISTRICT
# system125
# H-M-W SUD
# system126
# HANNAH NASH PUD
# system127
# HARRIS COUNTY DRAINAGE DIST 1
# system128
# HARRIS COUNTY DRAINAGE DIST 10
# system129
# HARRIS COUNTY DRAINAGE DIST 11
# system130
# HARRIS COUNTY DRAINAGE DIST 12
# system131
# HARRIS COUNTY DRAINAGE DIST 14
# system132
# HARRIS COUNTY DRAINAGE DIST 6
# system133
# HARRIS COUNTY DRAINAGE DIST 7
# system134
# HARRIS COUNTY DRAINAGE DIST 8
# system135
# HARRIS COUNTY DRAINAGE DIST 9
# system136
# HARRIS COUNTY EASTEX OAKS WATER-SEWER
# system137
# HARRIS COUNTY FCD
# system138
# HARRIS COUNTY FWSD 1
# system139
# HARRIS COUNTY FWSD 1-A
# system140
# HARRIS COUNTY FWSD 1-B
# system141
# HARRIS COUNTY FWSD 11
# system142
# HARRIS COUNTY FWSD 14
# system143
# HARRIS COUNTY FWSD 17
# system144
# HARRIS COUNTY FWSD 19
# system145
# HARRIS COUNTY FWSD 20
# system146
# HARRIS COUNTY FWSD 23
# system147
# HARRIS COUNTY FWSD 26
# system148
# HARRIS COUNTY FWSD 27
# system149
# HARRIS COUNTY FWSD 28
# system150
# HARRIS COUNTY FWSD 29
# system151
# HARRIS COUNTY FWSD 31
# system152
# HARRIS COUNTY FWSD 33
# system153
# HARRIS COUNTY FWSD 34
# system154
# HARRIS COUNTY FWSD 36
# system155
# HARRIS COUNTY FWSD 41
# system156
# HARRIS COUNTY FWSD 43
# system157
# HARRIS COUNTY FWSD 45
# system158
# HARRIS COUNTY FWSD 46
# system159
# HARRIS COUNTY FWSD 47
# system160
# HARRIS COUNTY FWSD 48
# system161
# HARRIS COUNTY FWSD 49
# system162
# HARRIS COUNTY FWSD 5
# system163
# HARRIS COUNTY FWSD 50
# system164
# HARRIS COUNTY FWSD 51
# system165
# HARRIS COUNTY FWSD 51
# system166
# HARRIS COUNTY FWSD 52
# system167
# HARRIS COUNTY FWSD 55
# system168
# HARRIS COUNTY FWSD 57
# system169
# HARRIS COUNTY FWSD 58
# system170
# HARRIS COUNTY FWSD 58
# system171
# HARRIS COUNTY FWSD 6
# system172
# HARRIS COUNTY FWSD 60
# system173
# HARRIS COUNTY FWSD 61
# system174
# HARRIS COUNTY FWSD 61
# system175
# HARRIS COUNTY FWSD 63
# system176
# HARRIS COUNTY FWSD 8
# system177
# HARRIS COUNTY HOUSTON SHIP CHANNEL NAVIGATION DISTRICT
# system178
# HARRIS COUNTY IMPROVEMENT DISTRICT 1
# system179
# HARRIS COUNTY IMPROVEMENT DISTRICT 1
# system180
# HARRIS COUNTY IMPROVEMENT DISTRICT 10
# system181
# HARRIS COUNTY IMPROVEMENT DISTRICT 10A
# system182
# HARRIS COUNTY IMPROVEMENT DISTRICT 11
# system183
# HARRIS COUNTY IMPROVEMENT DISTRICT 12
# system184
# HARRIS COUNTY IMPROVEMENT DISTRICT 13
# system185
# HARRIS COUNTY IMPROVEMENT DISTRICT 14
# system186
# HARRIS COUNTY IMPROVEMENT DISTRICT 15
# system187
# HARRIS COUNTY IMPROVEMENT DISTRICT 16
# system188
# HARRIS COUNTY IMPROVEMENT DISTRICT 17
# system189
# HARRIS COUNTY IMPROVEMENT DISTRICT 18
# system190
# HARRIS COUNTY IMPROVEMENT DISTRICT 2
# system191
# HARRIS COUNTY IMPROVEMENT DISTRICT 20
# system192
# HARRIS COUNTY IMPROVEMENT DISTRICT 21
# system193
# HARRIS COUNTY IMPROVEMENT DISTRICT 22
# system194
# HARRIS COUNTY IMPROVEMENT DISTRICT 23
# system195
# HARRIS COUNTY IMPROVEMENT DISTRICT 3
# system196
# HARRIS COUNTY IMPROVEMENT DISTRICT 4
# system197
# HARRIS COUNTY IMPROVEMENT DISTRICT 5
# system198
# HARRIS COUNTY IMPROVEMENT DISTRICT 7
# system199
# HARRIS COUNTY IMPROVEMENT DISTRICT 8
# system200
# HARRIS COUNTY IMPROVEMENT DISTRICT 9
# system201
# HARRIS COUNTY MUD 1
# system202
# HARRIS COUNTY MUD 10
# system203
# HARRIS COUNTY MUD 101
# system204
# HARRIS COUNTY MUD 102
# system205
# HARRIS COUNTY MUD 103
# system206
# HARRIS COUNTY MUD 104
# system207
# HARRIS COUNTY MUD 105
# system208
# HARRIS COUNTY MUD 106
# system209
# HARRIS COUNTY MUD 107
# system210
# HARRIS COUNTY MUD 109
# system211
# HARRIS COUNTY MUD 11
# system212
# HARRIS COUNTY MUD 114
# system213
# HARRIS COUNTY MUD 115
# system214
# HARRIS COUNTY MUD 118
# system215
# HARRIS COUNTY MUD 119
# system216
# HARRIS COUNTY MUD 120
# system217
# HARRIS COUNTY MUD 122
# system218
# HARRIS COUNTY MUD 123
# system219
# HARRIS COUNTY MUD 126
# system220
# HARRIS COUNTY MUD 127
# system221
# HARRIS COUNTY MUD 13
# system222
# HARRIS COUNTY MUD 130
# system223
# HARRIS COUNTY MUD 132
# system224
# HARRIS COUNTY MUD 136
# system225
# HARRIS COUNTY MUD 137
# system226
# HARRIS COUNTY MUD 139
# system227
# HARRIS COUNTY MUD 14
# system228
# HARRIS COUNTY MUD 142
# system229
# HARRIS COUNTY MUD 144
# system230
# HARRIS COUNTY MUD 145
# system231
# HARRIS COUNTY MUD 147
# system232
# HARRIS COUNTY MUD 148
# system233
# HARRIS COUNTY MUD 149
# system234
# HARRIS COUNTY MUD 15
# system235
# HARRIS COUNTY MUD 150
# system236
# HARRIS COUNTY MUD 151
# system237
# HARRIS COUNTY MUD 152
# system238
# HARRIS COUNTY MUD 153
# system239
# HARRIS COUNTY MUD 154
# system240
# HARRIS COUNTY MUD 155
# system241
# HARRIS COUNTY MUD 156
# system242
# HARRIS COUNTY MUD 157
# system243
# HARRIS COUNTY MUD 158
# system244
# HARRIS COUNTY MUD 159
# system245
# HARRIS COUNTY MUD 16
# system246
# HARRIS COUNTY MUD 162
# system247
# HARRIS COUNTY MUD 163
# system248
# HARRIS COUNTY MUD 165
# system249
# HARRIS COUNTY MUD 166
# system250
# HARRIS COUNTY MUD 167
# system251
# HARRIS COUNTY MUD 168
# system252
# HARRIS COUNTY MUD 169
# system253
# HARRIS COUNTY MUD 17
# system254
# HARRIS COUNTY MUD 170
# system255
# HARRIS COUNTY MUD 171
# system256
# HARRIS COUNTY MUD 172
# system257
# HARRIS COUNTY MUD 173
# system258
# HARRIS COUNTY MUD 175
# system259
# HARRIS COUNTY MUD 177
# system260
# HARRIS COUNTY MUD 179
# system261
# HARRIS COUNTY MUD 18
# system262
# HARRIS COUNTY MUD 180
# system263
# HARRIS COUNTY MUD 181
# system264
# HARRIS COUNTY MUD 182
# system265
# HARRIS COUNTY MUD 183
# system266
# HARRIS COUNTY MUD 184
# system267
# HARRIS COUNTY MUD 185
# system268
# HARRIS COUNTY MUD 186
# system269
# HARRIS COUNTY MUD 188
# system270
# HARRIS COUNTY MUD 189
# system271
# HARRIS COUNTY MUD 19
# system272
# HARRIS COUNTY MUD 191
# system273
# HARRIS COUNTY MUD 192
# system274
# HARRIS COUNTY MUD 194
# system275
# HARRIS COUNTY MUD 195
# system276
# HARRIS COUNTY MUD 196
# system277
# HARRIS COUNTY MUD 197
# system278
# HARRIS COUNTY MUD 199
# system279
# HARRIS COUNTY MUD 2
# system280
# HARRIS COUNTY MUD 20
# system281
# HARRIS COUNTY MUD 20
# system282
# HARRIS COUNTY MUD 200
# system283
# HARRIS COUNTY MUD 202
# system284
# HARRIS COUNTY MUD 203
# system285
# HARRIS COUNTY MUD 205
# system286
# HARRIS COUNTY MUD 208
# system287
# HARRIS COUNTY MUD 21
# system288
# HARRIS COUNTY MUD 211
# system289
# HARRIS COUNTY MUD 212
# system290
# HARRIS COUNTY MUD 213
# system291
# HARRIS COUNTY MUD 213-A
# system292
# HARRIS COUNTY MUD 213-B
# system293
# HARRIS COUNTY MUD 215
# system294
# HARRIS COUNTY MUD 216
# system295
# HARRIS COUNTY MUD 217
# system296
# HARRIS COUNTY MUD 218
# system297
# HARRIS COUNTY MUD 22
# system298
# HARRIS COUNTY MUD 220
# system299
# HARRIS COUNTY MUD 221
# system300
# HARRIS COUNTY MUD 222
# system301
# HARRIS COUNTY MUD 223
# system302
# HARRIS COUNTY MUD 225
# system303
# HARRIS COUNTY MUD 229
# system304
# HARRIS COUNTY MUD 23
# system305
# HARRIS COUNTY MUD 230
# system306
# HARRIS COUNTY MUD 231
# system307
# HARRIS COUNTY MUD 233
# system308
# HARRIS COUNTY MUD 236
# system309
# HARRIS COUNTY MUD 237
# system310
# HARRIS COUNTY MUD 238
# system311
# HARRIS COUNTY MUD 239
# system312
# HARRIS COUNTY MUD 24
# system313
# HARRIS COUNTY MUD 240
# system314
# HARRIS COUNTY MUD 243
# system315
# HARRIS COUNTY MUD 246
# system316
# HARRIS COUNTY MUD 247
# system317
# HARRIS COUNTY MUD 248
# system318
# HARRIS COUNTY MUD 249
# system319
# HARRIS COUNTY MUD 25
# system320
# HARRIS COUNTY MUD 250
# system321
# HARRIS COUNTY MUD 252
# system322
# HARRIS COUNTY MUD 254
# system323
# HARRIS COUNTY MUD 255
# system324
# HARRIS COUNTY MUD 256
# system325
# HARRIS COUNTY MUD 257
# system326
# HARRIS COUNTY MUD 259
# system327
# HARRIS COUNTY MUD 26
# system328
# HARRIS COUNTY MUD 26
# system329
# HARRIS COUNTY MUD 261
# system330
# HARRIS COUNTY MUD 262
# system331
# HARRIS COUNTY MUD 263
# system332
# HARRIS COUNTY MUD 264
# system333
# HARRIS COUNTY MUD 265
# system334
# HARRIS COUNTY MUD 266
# system335
# HARRIS COUNTY MUD 268
# system336
# HARRIS COUNTY MUD 27
# system337
# HARRIS COUNTY MUD 271
# system338
# HARRIS COUNTY MUD 272
# system339
# HARRIS COUNTY MUD 273
# system340
# HARRIS COUNTY MUD 275
# system341
# HARRIS COUNTY MUD 276
# system342
# HARRIS COUNTY MUD 277
# system343
# HARRIS COUNTY MUD 278
# system344
# HARRIS COUNTY MUD 279
# system345
# HARRIS COUNTY MUD 28
# system346
# HARRIS COUNTY MUD 280
# system347
# HARRIS COUNTY MUD 281
# system348
# HARRIS COUNTY MUD 282
# system349
# HARRIS COUNTY MUD 283
# system350
# HARRIS COUNTY MUD 284
# system351
# HARRIS COUNTY MUD 285
# system352
# HARRIS COUNTY MUD 286
# system353
# HARRIS COUNTY MUD 287
# system354
# HARRIS COUNTY MUD 288
# system355
# HARRIS COUNTY MUD 289
# system356
# HARRIS COUNTY MUD 29
# system357
# HARRIS COUNTY MUD 290
# system358
# HARRIS COUNTY MUD 291
# system359
# HARRIS COUNTY MUD 292
# system360
# HARRIS COUNTY MUD 294
# system361
# HARRIS COUNTY MUD 3
# system362
# HARRIS COUNTY MUD 30
# system363
# HARRIS COUNTY MUD 304
# system364
# HARRIS COUNTY MUD 306
# system365
# HARRIS COUNTY MUD 311
# system366
# HARRIS COUNTY MUD 316
# system367
# HARRIS COUNTY MUD 317
# system368
# HARRIS COUNTY MUD 318
# system369
# HARRIS COUNTY MUD 319
# system370
# HARRIS COUNTY MUD 321
# system371
# HARRIS COUNTY MUD 322
# system372
# HARRIS COUNTY MUD 324
# system373
# HARRIS COUNTY MUD 325
# system374
# HARRIS COUNTY MUD 327
# system375
# HARRIS COUNTY MUD 33
# system376
# HARRIS COUNTY MUD 341
# system377
# HARRIS COUNTY MUD 342
# system378
# HARRIS COUNTY MUD 343
# system379
# HARRIS COUNTY MUD 344
# system380
# HARRIS COUNTY MUD 345
# system381
# HARRIS COUNTY MUD 346
# system382
# HARRIS COUNTY MUD 347
# system383
# HARRIS COUNTY MUD 348
# system384
# HARRIS COUNTY MUD 35
# system385
# HARRIS COUNTY MUD 350
# system386
# HARRIS COUNTY MUD 351
# system387
# HARRIS COUNTY MUD 354
# system388
# HARRIS COUNTY MUD 355
# system389
# HARRIS COUNTY MUD 356
# system390
# HARRIS COUNTY MUD 358
# system391
# HARRIS COUNTY MUD 359
# system392
# HARRIS COUNTY MUD 36
# system393
# HARRIS COUNTY MUD 360
# system394
# HARRIS COUNTY MUD 361
# system395
# HARRIS COUNTY MUD 364
# system396
# HARRIS COUNTY MUD 365
# system397
# HARRIS COUNTY MUD 366
# system398
# HARRIS COUNTY MUD 367
# system399
# HARRIS COUNTY MUD 368
# system400
# HARRIS COUNTY MUD 370
# system401
# HARRIS COUNTY MUD 371
# system402
# HARRIS COUNTY MUD 372
# system403
# HARRIS COUNTY MUD 373
# system404
# HARRIS COUNTY MUD 374
# system405
# HARRIS COUNTY MUD 375
# system406
# HARRIS COUNTY MUD 376
# system407
# HARRIS COUNTY MUD 377
# system408
# HARRIS COUNTY MUD 378
# system409
# HARRIS COUNTY MUD 379
# system410
# HARRIS COUNTY MUD 380
# system411
# HARRIS COUNTY MUD 381
# system412
# HARRIS COUNTY MUD 382
# system413
# HARRIS COUNTY MUD 383
# system414
# HARRIS COUNTY MUD 385
# system415
# HARRIS COUNTY MUD 387
# system416
# HARRIS COUNTY MUD 388
# system417
# HARRIS COUNTY MUD 389
# system418
# HARRIS COUNTY MUD 39
# system419
# HARRIS COUNTY MUD 390
# system420
# HARRIS COUNTY MUD 391
# system421
# HARRIS COUNTY MUD 393
# system422
# HARRIS COUNTY MUD 396
# system423
# HARRIS COUNTY MUD 397
# system424
# HARRIS COUNTY MUD 399
# system425
# HARRIS COUNTY MUD 4
# system426
# HARRIS COUNTY MUD 40
# system427
# HARRIS COUNTY MUD 400
# system428
# HARRIS COUNTY MUD 401
# system429
# HARRIS COUNTY MUD 402
# system430
# HARRIS COUNTY MUD 403
# system431
# HARRIS COUNTY MUD 404
# system432
# HARRIS COUNTY MUD 405
# system433
# HARRIS COUNTY MUD 406
# system434
# HARRIS COUNTY MUD 407
# system435
# HARRIS COUNTY MUD 409
# system436
# HARRIS COUNTY MUD 410
# system437
# HARRIS COUNTY MUD 411
# system438
# HARRIS COUNTY MUD 412
# system439
# HARRIS COUNTY MUD 415
# system440
# HARRIS COUNTY MUD 416
# system441
# HARRIS COUNTY MUD 418
# system442
# HARRIS COUNTY MUD 419
# system443
# HARRIS COUNTY MUD 42
# system444
# HARRIS COUNTY MUD 420
# system445
# HARRIS COUNTY MUD 421
# system446
# HARRIS COUNTY MUD 422
# system447
# HARRIS COUNTY MUD 423
# system448
# HARRIS COUNTY MUD 424
# system449
# HARRIS COUNTY MUD 425
# system450
# HARRIS COUNTY MUD 426
# system451
# HARRIS COUNTY MUD 427
# system452
# HARRIS COUNTY MUD 428
# system453
# HARRIS COUNTY MUD 429
# system454
# HARRIS COUNTY MUD 43
# system455
# HARRIS COUNTY MUD 432
# system456
# HARRIS COUNTY MUD 433
# system457
# HARRIS COUNTY MUD 434
# system458
# HARRIS COUNTY MUD 435
# system459
# HARRIS COUNTY MUD 436
# system460
# HARRIS COUNTY MUD 437
# system461
# HARRIS COUNTY MUD 438
# system462
# HARRIS COUNTY MUD 439
# system463
# HARRIS COUNTY MUD 44
# system464
# HARRIS COUNTY MUD 441
# system465
# HARRIS COUNTY MUD 449
# system466
# HARRIS COUNTY MUD 45
# system467
# HARRIS COUNTY MUD 450
# system468
# HARRIS COUNTY MUD 451
# system469
# HARRIS COUNTY MUD 452
# system470
# HARRIS COUNTY MUD 454
# system471
# HARRIS COUNTY MUD 457
# system472
# HARRIS COUNTY MUD 458
# system473
# HARRIS COUNTY MUD 459
# system474
# HARRIS COUNTY MUD 46
# system475
# HARRIS COUNTY MUD 460
# system476
# HARRIS COUNTY MUD 461
# system477
# HARRIS COUNTY MUD 462
# system478
# HARRIS COUNTY MUD 463
# system479
# HARRIS COUNTY MUD 464
# system480
# HARRIS COUNTY MUD 465
# system481
# HARRIS COUNTY MUD 468
# system482
# HARRIS COUNTY MUD 473
# system483
# HARRIS COUNTY MUD 476
# system484
# HARRIS COUNTY MUD 477
# system485
# HARRIS COUNTY MUD 478
# system486
# HARRIS COUNTY MUD 479
# system487
# HARRIS COUNTY MUD 48
# system488
# HARRIS COUNTY MUD 480
# system489
# HARRIS COUNTY MUD 481
# system490
# HARRIS COUNTY MUD 482
# system491
# HARRIS COUNTY MUD 483
# system492
# HARRIS COUNTY MUD 484
# system493
# HARRIS COUNTY MUD 485
# system494
# HARRIS COUNTY MUD 488
# system495
# HARRIS COUNTY MUD 489
# system496
# HARRIS COUNTY MUD 49
# system497
# HARRIS COUNTY MUD 490
# system498
# HARRIS COUNTY MUD 491
# system499
# HARRIS COUNTY MUD 492
# system500
# HARRIS COUNTY MUD 493
# system501
# HARRIS COUNTY MUD 494
# system502
# HARRIS COUNTY MUD 495
# system503
# HARRIS COUNTY MUD 496
# system504
# HARRIS COUNTY MUD 497
# system505
# HARRIS COUNTY MUD 498
# system506
# HARRIS COUNTY MUD 499
# system507
# HARRIS COUNTY MUD 5
# system508
# HARRIS COUNTY MUD 50
# system509
# HARRIS COUNTY MUD 500
# system510
# HARRIS COUNTY MUD 501
# system511
# HARRIS COUNTY MUD 502
# system512
# HARRIS COUNTY MUD 503
# system513
# HARRIS COUNTY MUD 504
# system514
# HARRIS COUNTY MUD 505
# system515
# HARRIS COUNTY MUD 506
# system516
# HARRIS COUNTY MUD 51
# system517
# HARRIS COUNTY MUD 510
# system518
# HARRIS COUNTY MUD 514
# system519
# HARRIS COUNTY MUD 515
# system520
# HARRIS COUNTY MUD 516
# system521
# HARRIS COUNTY MUD 517
# system522
# HARRIS COUNTY MUD 518
# system523
# HARRIS COUNTY MUD 519
# system524
# HARRIS COUNTY MUD 52
# system525
# HARRIS COUNTY MUD 520
# system526
# HARRIS COUNTY MUD 524
# system527
# HARRIS COUNTY MUD 525
# system528
# HARRIS COUNTY MUD 528
# system529
# HARRIS COUNTY MUD 529
# system530
# HARRIS COUNTY MUD 53
# system531
# HARRIS COUNTY MUD 530
# system532
# HARRIS COUNTY MUD 531
# system533
# HARRIS COUNTY MUD 532
# system534
# HARRIS COUNTY MUD 533
# system535
# HARRIS COUNTY MUD 534
# system536
# HARRIS COUNTY MUD 535
# system537
# HARRIS COUNTY MUD 536
# system538
# HARRIS COUNTY MUD 537
# system539
# HARRIS COUNTY MUD 538
# system540
# HARRIS COUNTY MUD 539
# system541
# HARRIS COUNTY MUD 540
# system542
# HARRIS COUNTY MUD 541
# system543
# HARRIS COUNTY MUD 542
# system544
# HARRIS COUNTY MUD 543
# system545
# HARRIS COUNTY MUD 545
# system546
# HARRIS COUNTY MUD 546
# system547
# HARRIS COUNTY MUD 55
# system548
# HARRIS COUNTY MUD 58
# system549
# HARRIS COUNTY MUD 6
# system550
# HARRIS COUNTY MUD 61
# system551
# HARRIS COUNTY MUD 62
# system552
# HARRIS COUNTY MUD 63
# system553
# HARRIS COUNTY MUD 64
# system554
# HARRIS COUNTY MUD 65
# system555
# HARRIS COUNTY MUD 67
# system556
# HARRIS COUNTY MUD 69
# system557
# HARRIS COUNTY MUD 7
# system558
# HARRIS COUNTY MUD 70
# system559
# HARRIS COUNTY MUD 71
# system560
# HARRIS COUNTY MUD 71
# system561
# HARRIS COUNTY MUD 72
# system562
# HARRIS COUNTY MUD 73
# system563
# HARRIS COUNTY MUD 73
# system564
# HARRIS COUNTY MUD 74
# system565
# HARRIS COUNTY MUD 75
# system566
# HARRIS COUNTY MUD 77
# system567
# HARRIS COUNTY MUD 8
# system568
# HARRIS COUNTY MUD 80
# system569
# HARRIS COUNTY MUD 81
# system570
# HARRIS COUNTY MUD 82
# system571
# HARRIS COUNTY MUD 85
# system572
# HARRIS COUNTY MUD 86
# system573
# HARRIS COUNTY MUD 9
# system574
# HARRIS COUNTY MUD 90
# system575
# HARRIS COUNTY MUD 91
# system576
# HARRIS COUNTY MUD 92
# system577
# HARRIS COUNTY MUD 93
# system578
# HARRIS COUNTY MUD 96
# system579
# HARRIS COUNTY MUD 97
# system580
# HARRIS COUNTY MUD 98
# system581
# HARRIS COUNTY MUNICIPAL MANAGEMENT DISTRICT 1
# system582
# HARRIS COUNTY REGIONAL DISTRICT 2
# system583
# HARRIS COUNTY ROAD IMPROVEMENT DISTRICT 1
# system584
# HARRIS COUNTY ROAD IMPROVEMENT DISTRICT 2
# system585
# HARRIS COUNTY SANITATION AUTHORITY
# system586
# HARRIS COUNTY UTILITY DISTRICT 1
# system587
# HARRIS COUNTY UTILITY DISTRICT 10
# system588
# HARRIS COUNTY UTILITY DISTRICT 11
# system589
# HARRIS COUNTY UTILITY DISTRICT 12
# system590
# HARRIS COUNTY UTILITY DISTRICT 13
# system591
# HARRIS COUNTY UTILITY DISTRICT 14
# system592
# HARRIS COUNTY UTILITY DISTRICT 15
# system593
# HARRIS COUNTY UTILITY DISTRICT 16
# system594
# HARRIS COUNTY UTILITY DISTRICT 2
# system595
# HARRIS COUNTY UTILITY DISTRICT 3
# system596
# HARRIS COUNTY UTILITY DISTRICT 3
# system597
# HARRIS COUNTY UTILITY DISTRICT 4
# system598
# HARRIS COUNTY UTILITY DISTRICT 5
# system599
# HARRIS COUNTY UTILITY DISTRICT 6
# system600
# HARRIS COUNTY UTILITY DISTRICT 6
# system601
# HARRIS COUNTY UTILITY DISTRICT 7
# system602
# HARRIS COUNTY UTILITY DISTRICT 8
# system603
# HARRIS COUNTY UTILITY DISTRICT 9
# system604
# HARRIS COUNTY WATER IMPROVEMENT DISTRICT 10
# system605
# HARRIS COUNTY WCID 1
# system606
# HARRIS COUNTY WCID 10
# system607
# HARRIS COUNTY WCID 104
# system608
# HARRIS COUNTY WCID 104
# system609
# HARRIS COUNTY WCID 108
# system610
# HARRIS COUNTY WCID 109
# system611
# HARRIS COUNTY WCID 109
# system612
# HARRIS COUNTY WCID 11
# system613
# HARRIS COUNTY WCID 110
# system614
# HARRIS COUNTY WCID 110
# system615
# HARRIS COUNTY WCID 111
# system616
# HARRIS COUNTY WCID 111
# system617
# HARRIS COUNTY WCID 112
# system618
# HARRIS COUNTY WCID 112
# system619
# HARRIS COUNTY WCID 113
# system620
# HARRIS COUNTY WCID 114
# system621
# HARRIS COUNTY WCID 114
# system622
# HARRIS COUNTY WCID 116
# system623
# HARRIS COUNTY WCID 119
# system624
# HARRIS COUNTY WCID 119
# system625
# HARRIS COUNTY WCID 12
# system626
# HARRIS COUNTY WCID 123
# system627
# HARRIS COUNTY WCID 129
# system628
# HARRIS COUNTY WCID 13
# system629
# HARRIS COUNTY WCID 132
# system630
# HARRIS COUNTY WCID 132
# system631
# HARRIS COUNTY WCID 133
# system632
# HARRIS COUNTY WCID 133
# system633
# HARRIS COUNTY WCID 134
# system634
# HARRIS COUNTY WCID 136
# system635
# HARRIS COUNTY WCID 136
# system636
# HARRIS COUNTY WCID 137
# system637
# HARRIS COUNTY WCID 14
# system638
# HARRIS COUNTY WCID 140
# system639
# HARRIS COUNTY WCID 145
# system640
# HARRIS COUNTY WCID 15
# system641
# HARRIS COUNTY WCID 155
# system642
# HARRIS COUNTY WCID 156
# system643
# HARRIS COUNTY WCID 157
# system644
# HARRIS COUNTY WCID 158
# system645
# HARRIS COUNTY WCID 159
# system646
# HARRIS COUNTY WCID 16
# system647
# HARRIS COUNTY WCID 160
# system648
# HARRIS COUNTY WCID 161
# system649
# HARRIS COUNTY WCID 163
# system650
# HARRIS COUNTY WCID 18
# system651
# HARRIS COUNTY WCID 19
# system652
# HARRIS COUNTY WCID 2
# system653
# HARRIS COUNTY WCID 20
# system654
# HARRIS COUNTY WCID 21
# system655
# HARRIS COUNTY WCID 22
# system656
# HARRIS COUNTY WCID 24
# system657
# HARRIS COUNTY WCID 25
# system658
# HARRIS COUNTY WCID 26
# system659
# HARRIS COUNTY WCID 27
# system660
# HARRIS COUNTY WCID 29
# system661
# HARRIS COUNTY WCID 3
# system662
# HARRIS COUNTY WCID 30
# system663
# HARRIS COUNTY WCID 31
# system664
# HARRIS COUNTY WCID 32
# system665
# HARRIS COUNTY WCID 33
# system666
# HARRIS COUNTY WCID 34
# system667
# HARRIS COUNTY WCID 36
# system668
# HARRIS COUNTY WCID 39
# system669
# HARRIS COUNTY WCID 40
# system670
# HARRIS COUNTY WCID 41
# system671
# HARRIS COUNTY WCID 42
# system672
# HARRIS COUNTY WCID 44
# system673
# HARRIS COUNTY WCID 45
# system674
# HARRIS COUNTY WCID 47
# system675
# HARRIS COUNTY WCID 49
# system676
# HARRIS COUNTY WCID 50
# system677
# HARRIS COUNTY WCID 51
# system678
# HARRIS COUNTY WCID 52
# system679
# HARRIS COUNTY WCID 53
# system680
# HARRIS COUNTY WCID 54
# system681
# HARRIS COUNTY WCID 55
# system682
# HARRIS COUNTY WCID 56
# system683
# HARRIS COUNTY WCID 57
# system684
# HARRIS COUNTY WCID 58
# system685
# HARRIS COUNTY WCID 59
# system686
# HARRIS COUNTY WCID 6
# system687
# HARRIS COUNTY WCID 60
# system688
# HARRIS COUNTY WCID 62
# system689
# HARRIS COUNTY WCID 63
# system690
# HARRIS COUNTY WCID 65
# system691
# HARRIS COUNTY WCID 69
# system692
# HARRIS COUNTY WCID 7
# system693
# HARRIS COUNTY WCID 70
# system694
# HARRIS COUNTY WCID 71
# system695
# HARRIS COUNTY WCID 73
# system696
# HARRIS COUNTY WCID 74
# system697
# HARRIS COUNTY WCID 75
# system698
# HARRIS COUNTY WCID 76
# system699
# HARRIS COUNTY WCID 78
# system700
# HARRIS COUNTY WCID 79
# system701
# HARRIS COUNTY WCID 8
# system702
# HARRIS COUNTY WCID 81
# system703
# HARRIS COUNTY WCID 82
# system704
# HARRIS COUNTY WCID 83
# system705
# HARRIS COUNTY WCID 84
# system706
# HARRIS COUNTY WCID 87
# system707
# HARRIS COUNTY WCID 89
# system708
# HARRIS COUNTY WCID 89
# system709
# HARRIS COUNTY WCID 9
# system710
# HARRIS COUNTY WCID 90
# system711
# HARRIS COUNTY WCID 91
# system712
# HARRIS COUNTY WCID 92
# system713
# HARRIS COUNTY WCID 92
# system714
# HARRIS COUNTY WCID 93
# system715
# HARRIS COUNTY WCID 93
# system716
# HARRIS COUNTY WCID 94
# system717
# HARRIS COUNTY WCID 95
# system718
# HARRIS COUNTY WCID 96
# system719
# HARRIS COUNTY WCID 97
# system720
# HARRIS COUNTY WCID 98
# system721
# HARRIS COUNTY WCID 99
# system722
# HARRIS COUNTY WCID-FONDREN ROAD
# system723
# HARRIS FORT BEND COUNTIES MUD 1
# system724
# HARRIS FORT BEND COUNTIES MUD 3
# system725
# HARRIS FORT BEND COUNTIES MUD 5
# system726
# HARRIS GALVESTON SUBSIDENCE DISTRICT
# system727
# HARRIS IMPROVEMENT DISTRICT
# system728
# HARRIS-BRAZORIA COUNTIES MUD 509
# system729
# HARRIS-MONTGOMERY COUNTIES MUD 386
# system730
# HARRIS-WALLER COUNTIES MUD 2
# system731
# HARRIS-WALLER COUNTIES MUD 3
# system732
# HEATHERLOCH MUD
# system733
# HORSEPEN BAYOU MUD
# system734
# HORSEPEN BAYOU MUD
# system735
# HOUSTON DOWNTOWN MANAGEMENT DISTRICT
# system736
# HUFFSMITH ROAD PUD
# system737
# HUNTERS GLEN MUD
# system738
# HUNTERWOOD MUD
# system739
# IMPERIAL VALLEY MUD
# system740
# INTERCONTINENTAL CROSSING MUD
# system741
# INTERCONTINENTAL MUD
# system742
# INTERNATIONAL MANAGEMENT DISTRICT
# system743
# INTERSTATE MUD
# system744
# INTERWOOD MUD
# system745
# INVERNESS FOREST IMPROVEMENT DISTRICT
# system746
# JACKRABBIT ROAD PUD
# system747
# JETERO PUD
# system748
# JFK MUD
# system749
# KATY MANAGEMENT DISTRICT 1
# system750
# KINGS MANOR MUD
# system751
# KINGSBRIDGE MUD
# system752
# KIRKMONT MUD
# system753
# KLEIN PUD
# system754
# KLEINWOOD MUD
# system755
# KUYKENDAHL ROAD PUD 1
# system756
# KUYKENDAHL ROAD PUD 2
# system757
# LA PORTE AREA WATER AUTHORITY
# system758
# LA PORTE UTILITY DISTRICT
# system759
# LAKE FOREST UTILITY DISTRICT
# system760
# LAKE MUD
# system761
# LANGHAM CREEK UTILITY DISTRICT
# system762
# LANGHAM CREEK UTILITY DISTRICT
# system763
# LITTLE YORK MUD
# system764
# LITTLE YORK MUD
# system765
# LONGHORN TOWN UTILITY DISTRICT
# system766
# LOUETTA NORTH PUD
# system767
# LOUETTA ROAD UTILITY DISTRICT
# system768
# LOUETTA ROAD UTILITY DISTRICT
# system769
# LOWER KIRBY PEARLAND MANAGEMENT DISTRICT
# system770
# LUCE BAYOU PUD
# system771
# LYNCHBURG UTILITY DISTRICT
# system772
# MALCOMSON ROAD UTILITY DISTRICT
# system773
# MANNING UTILITY DISTRICT
# system774
# MARKET STREET FWSD 5
# system775
# MARKHAM MUD
# system776
# MASON CREEK UTILITY DISTRICT
# system777
# MAY PUD
# system778
# MAYDE CREEK MUD
# system779
# MEADOWHILL REGIONAL MUD
# system780
# MELROSE PARK MUD
# system781
# MELROSE PARK MUD
# system782
# MEMORIAL HILLS UTILITY DISTRICT
# system783
# MEMORIAL MUD
# system784
# MEMORIAL VILLAGES WATER AUTHORITY
# system785
# MEMORIAL WEST MUD
# system786
# MEMORIAL WEST UTILITY DISTRICT
# system787
# MEMORIAL WEST UTILITY DISTRICT
# system788
# MIDTOWN MANAGEMENT DISTRICT
# system789
# MILLS ROAD MUD
# system790
# MISSION BEND MUD 1
# system791
# MISSION BEND MUD 2
# system792
# MONTROSE MANAGEMENT DISTRICT
# system793
# MORTON ROAD MUD
# system794
# MOSSY OAKS UTILITY DISTRICT
# system795
# MOUNT HOUSTON ROAD MUD
# system796
# NASA AREA MANAGEMENT DISTRICT
# system797
# NEAR NORTHSIDE MANAGEMENT DISTRICT
# system798
# NEAR NORTHWEST MANAGEMENT DISTRICT
# system799
# NEWPORT MUD
# system800
# NORCHESTER MUD
# system801
# NORTH BELT UTILITY DISTRICT
# system802
# NORTH BELT UTILITY DISTRICT
# system803
# NORTH CHANNEL WATER AUTHORITY
# system804
# NORTH FOREST MUD
# system805
# NORTH FOREST MUD
# system806
# NORTH GREEN MUD
# system807
# NORTH HARRIS COUNTY MUD 1
# system808
# NORTH HARRIS COUNTY REGIONAL WATER AUTHORITY
# system809
# NORTH HOUSTON DISTRICT
# system810
# NORTH PARK PUD
# system811
# NORTHAMPTON MUD
# system812
# NORTHBOROUGH MUD
# system813
# NORTHBROOK MUD
# system814
# NORTHEAST HARRIS COUNTY MUD 1
# system815
# NORTHGATE CROSSING MUD 1
# system816
# NORTHGATE CROSSING MUD 2
# system817
# NORTHGATE CROSSING MUD 3
# system818
# NORTHGATE CROSSING ROAD UTILITY DISTRICT
# system819
# NORTHGATE UTILITY DISTRICT
# system820
# NORTHPOINTE WCID
# system821
# NORTHWAY MUD
# system822
# NORTHWEST FREEWAY MUD
# system823
# NORTHWEST HARRIS COUNTY MUD 10
# system824
# NORTHWEST HARRIS COUNTY MUD 12
# system825
# NORTHWEST HARRIS COUNTY MUD 15
# system826
# NORTHWEST HARRIS COUNTY MUD 16
# system827
# NORTHWEST HARRIS COUNTY MUD 19
# system828
# NORTHWEST HARRIS COUNTY MUD 20
# system829
# NORTHWEST HARRIS COUNTY MUD 21
# system830
# NORTHWEST HARRIS COUNTY MUD 22
# system831
# NORTHWEST HARRIS COUNTY MUD 23
# system832
# NORTHWEST HARRIS COUNTY MUD 24
# system833
# NORTHWEST HARRIS COUNTY MUD 25
# system834
# NORTHWEST HARRIS COUNTY MUD 27
# system835
# NORTHWEST HARRIS COUNTY MUD 28
# system836
# NORTHWEST HARRIS COUNTY MUD 29
# system837
# NORTHWEST HARRIS COUNTY MUD 30
# system838
# NORTHWEST HARRIS COUNTY MUD 32
# system839
# NORTHWEST HARRIS COUNTY MUD 36
# system840
# NORTHWEST HARRIS COUNTY MUD 5
# system841
# NORTHWEST HARRIS COUNTY MUD 6
# system842
# NORTHWEST HARRIS COUNTY MUD 7
# system843
# NORTHWEST HARRIS COUNTY MUD 8
# system844
# NORTHWEST HARRIS COUNTY MUD 9
# system845
# NORTHWEST HARRIS COUNTY PUD 1
# system846
# NORTHWEST HARRIS COUNTY PUD 2
# system847
# NORTHWEST HARRIS COUNTY PUD 3
# system848
# NORTHWEST MUD
# system849
# NORTHWEST PARK MUD
# system850
# NORTHWOOD MUD 1
# system851
# NOTTINGHAM COUNTRY MUD
# system852
# OAKMONT PUBLIC UTILITY DISTRICT
# system853
# OLD TOWN SPRING IMPROVEMENT DISTRICT
# system854
# PARK TEN MUD
# system855
# PARKGLEN MUD
# system856
# PARKGLEN WEST MUD
# system857
# PARKWAY UTILITY DISTRICT
# system858
# PARKWAY UTILITY DISTRICT
# system859
# PEARLAND MUNICIPAL MANAGEMENT DIST 1
# system860
# PECAN PARK MUD
# system861
# PINE BOUGH PUD
# system862
# PINE FOREST MUD
# system863
# PINE FOREST PUD
# system864
# PINE VILLAGE PUD
# system865
# PONDEROSA FOREST UTILITY DISTRICT
# system866
# PONDEROSA FOREST UTILITY DISTRICT
# system867
# PORT OF HOUSTON AUTHORITY
# system868
# POST WOOD MUD
# system869
# PRESTONWOOD FOREST UTILITY DISTRICT
# system870
# PRESTONWOOD PUD
# system871
# RANKIN ROAD WEST MUD
# system872
# REID ROAD MUD 1
# system873
# REID ROAD MUD 2
# system874
# REID ROAD MUD 2
# system875
# REMINGTON MUD 1
# system876
# REMINGTON MUD 2
# system877
# REMINGTON MUD 3
# system878
# RENN ROAD MUD
# system879
# RHEA UTILITY DISTRICT
# system880
# RICEWOOD MUD
# system881
# RICHEY ROAD MUD
# system882
# RIDGEMONT MUD
# system883
# ROBIN PUD
# system884
# ROLLING CREEK UTILITY DISTRICT
# system885
# ROLLING FORK PUD
# system886
# ROSEWOOD MUD
# system887
# ROYALWOOD MUD
# system888
# ROYALWOOD MUD
# system889
# SAGEBEND MUD
# system890
# SAGEGLEN MUD
# system891
# SAGEMEADOW UTILITY DISTRICT
# system892
# SAGEMONT MUD
# system893
# SAINT GEORGE PLACE MANAGEMENT DISTRICT
# system894
# SAN JACINTO CONSERVATION RECLAMATION DISTRICT
# system895
# SAN JACINTO PLACE MUD 1
# system896
# SAN JACINTO PLACE MUD 2
# system897
# SAN JACINTO PLACE MUD 3
# system898
# SAN JACINTO PLACE MUD 4
# system899
# SCARSDALE MUD
# system900
# SEQUOIA IMPROVEMENT DISTRICT
# system901
# SHASLA PUD
# system902
# SHELDON ROAD MUD
# system903
# SOUTHBEND MUD
# system904
# SOUTHWEST HARRIS COUNTY MUD 1
# system905
# SOUTHWEST MANAGEMENT DISTRICT
# system906
# SPANISH COVE PUD
# system907
# SPECTRUM MANAGEMENT DISTRICT
# system908
# SPENCER ROAD PUD
# system909
# SPENWICK PLACE MUD
# system910
# SPRING BRANCH MANAGEMENT DISTRICT
# system911
# SPRING CREEK FOREST PUD
# system912
# SPRING MEADOWS MUD
# system913
# SPRING MEADOWS MUD
# system914
# SPRING PUD
# system915
# SPRING WEST MUD
# system916
# SUNBELT FWSD
# system917
# TALL TIMBERS UTILITY DISTRICT
# system918
# TATTOR ROAD MUNICIPAL DISTRICT
# system919
# TERRANOVA WEST MUD
# system920
# THOMPSON ROAD UTILITY DISTRICT
# system921
# THOMPSON ROAD UTILITY DISTRICT
# system922
# THREE LAKES MUD 1
# system923
# TIDWELL TIMBERS MUD
# system924
# TIDWELL TIMBERS MUD
# system925
# TIMBER LANE UTILITY DISTRICT
# system926
# TIMBER LANE UTILITY DISTRICT
# system927
# TIMBERLAKE IMPROVEMENT DISTRICT
# system928
# TIMBERLAKE IRRIGATION DIST
# system929
# TOMBALL ROAD UTILITY DISTRICT
# system930
# TOWER OAKS PLAZA MUD
# system931
# TOWNE LAKE MANAGEMENT DISTRICT
# system932
# TRAIL OF THE LAKES MUD
# system933
# TREELINE IMPROVEMENT DISTRICT
# system934
# TRI-CITY FWSD 2
# system935
# TURKEY CREEK IMPROVEMENT DISTRICT
# system936
# UPPER KIRBY MANAGEMENT DISTRICT
# system937
# VILLAGE AT KATY DEVELOPMENT DISTRICT
# system938
# WALLER TOWN CENTER MANAGEMENT DISTRICT
# system939
# WEST BELT MUD
# system940
# WEST HARRIS COUNTY MUD 1
# system941
# WEST HARRIS COUNTY MUD 10
# system942
# WEST HARRIS COUNTY MUD 11
# system943
# WEST HARRIS COUNTY MUD 14
# system944
# WEST HARRIS COUNTY MUD 15
# system945
# WEST HARRIS COUNTY MUD 16
# system946
# WEST HARRIS COUNTY MUD 17
# system947
# WEST HARRIS COUNTY MUD 2
# system948
# WEST HARRIS COUNTY MUD 20
# system949
# WEST HARRIS COUNTY MUD 21
# system950
# WEST HARRIS COUNTY MUD 4
# system951
# WEST HARRIS COUNTY MUD 5
# system952
# WEST HARRIS COUNTY MUD 6
# system953
# WEST HARRIS COUNTY MUD 7
# system954
# WEST HARRIS COUNTY MUD 8
# system955
# WEST HARRIS COUNTY MUD 9
# system956
# WEST HARRIS COUNTY RWA
# system957
# WEST HOUSTON MUD
# system958
# WEST KEEGANS BAYOU IMPROVEMENT DISTRICT
# system959
# WEST MEMORIAL MUD
# system960
# WEST PARK MUD
# system961
# WEST RANCH MANAGEMENT DISTRICT
# system962
# WEST ROAD IMPROVEMENT DISTRICT
# system963
# WEST ROAD IMPROVEMENT DISTRICT
# system964
# WEST ROAD IMPROVEMENT DISTRICT
# system965
# WESTADOR MUD
# system966
# WESTADOR MUD
# system967
# WESTBOURNE WCID
# system968
# WESTCHASE AREA MANAGEMENT DISTRICT
# system969
# WESTCHASE DISTRICT
# system970
# WESTCHESTER MUD
# system971
# WESTCREST UTILITY DISTRICT
# system972
# WESTHEIMER ROAD MUD
# system973
# WESTHEIMER ROAD MUD
# system974
# WESTLAKE MUD 1
# system975
# WESTON MUD
# system976
# WESTWAY UTILITY DISTRICT
# system977
# WHITE OAK BEND MUD
# system978
# WHITE OAK MUD
# system979
# WHITE OAK/1960 MUD
# system980
# WILCREST IMPROVEMENT DISTRICT
# system981
# WILLOW CHASE MUD
# system982
# WILLOW FORK DRAINAGE DISTRICT
# system983
# WINDFERN FOREST UTILITY DISTRICT
# system984
# WINDFERN MUD
# system985
# WOOD BEND MUD
# system986
# WOODCREEK MUD
# system987
# WOODFOREST NORTH UTILITY DISTRICT
# system988
# WOODLAND NORTH UTILITY DISTRICT
# system989
# WORTHAM PARK MUD
# system990
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-fba8ee82a5d2> in <module>()
#      46     temp_status = driver.find_elements_by_css_selector(css_find_status)
#      47     temp_number = driver.find_elements_by_css_selector(css_find_number)
# ---> 48     System.append(temp_wd[count].text)
#      49     Status.append(temp_status[count].text)
#      50     ID.append(temp_number[count].text)
#
# IndexError: list index out of range

# %%
system_list_df = pd.DataFrame({'Name': System, 'Status': Status,'ID': ID,'County': 'HARRIS'})
#empty_dww = empty_dww.append(system_list_df)       
#harris_dww = system_list_df
system_list_df.to_csv('../Input/tceq_audits/harris_base.csv')
