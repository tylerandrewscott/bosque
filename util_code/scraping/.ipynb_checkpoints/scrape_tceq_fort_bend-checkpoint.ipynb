# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

empty_dww = pd.DataFrame()
empty_district_info = pd.DataFrame()
empty_audit_info = pd.DataFrame()
driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
base_page = 'http://www14.tceq.texas.gov/iwud/dist/index.cfm?fuseaction=ListDistricts&COMMAND=LIST&compress=N&StartName=&ID=&RegionCode=&DistTypeCode=&CreationTypeCode=&DistFunctionTypeCode=&CountyCode=&FinancialStatus=&ActivityStatus=&ListStart='
driver.get(base_page)
#CountyCode

houston_counties = [79,101,170]

from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
#
# select by value 
#select.select_by_value('1')
#wait = WebDriverWait(driver, 10)
select = Select(driver.find_element_by_css_selector('#CountyCode'))
wd_info_call = '.iwuddata:nth-child(2)'
#wd_info_header = 'tr:nth-child(5) .iwudheading , .iwudheading:nth-child(1)'
wd_info_header = '.iwudheading:nth-child(1)'
#for county in houston_counties:
count = 0
select_county = Select(driver.find_element_by_css_selector('#CountyCode'))
select_county.select_by_value(str(79))
driver.find_elements_by_css_selector('input')[1].click()
css_find_wds = "table+ table .iwud a"
css_find_number = '.iwud+ .iwud:nth-child(3)'
css_find_status = '.iwud~ .iwud+ .iwud'
css_to_click_more = "table+ table tr:nth-child(1) a:nth-child(1) img"
audit_vars_css = 'td.iwud:nth-child(1)'
audit_vals_css = '.iwud+ td'
get_doc_id = 'table:nth-child(6) tr:nth-child(1) .iwuddata'
access_more_docs = '.iwudgreyrow~ tr a img'

System = [];Status = []; ID = []
#### Grab basic district info
count = 0

for system in range(2000):
    print('system' + str(system))
    temp_wd = driver.find_elements_by_css_selector(css_find_wds)
    temp_status = driver.find_elements_by_css_selector(css_find_status)
    temp_number = driver.find_elements_by_css_selector(css_find_number)
    System.append(temp_wd[count].text)
    Status.append(temp_status[count].text)
    ID.append(temp_number[count].text)
    water_systems = driver.find_elements_by_css_selector(css_find_wds)
    #for systems in range(len(water_systems)):
    temp_name = driver.find_elements_by_css_selector(css_find_wds)[count].text
    print(temp_name)
    temp_id = driver.find_elements_by_css_selector(css_find_number)[count].text
    driver.find_elements_by_css_selector(css_find_wds)[count].click()
    info_vars = []
    info = []
    for el in driver.find_elements_by_css_selector(wd_info_call):
        info.append(el.text)
    for el in driver.find_elements_by_css_selector(wd_info_header):
        info_vars.append(el.text)
    i = 0
    for v in range(len(info_vars)):
        if info_vars[v] == '':
            i = i + 1
            info_vars[v] = str(i)
            #print(info_vars);print(info)
    temp = pd.DataFrame(info).T
    temp.columns = [info_vars]
    temp['NAME'] = temp_name
    temp['WDD_ID'] = temp_id
    #for dup in range(sum(temp.columns.duplicated())):
    while sum(temp.columns.duplicated())>0:
        temp = temp.drop(temp.columns[temp.columns.duplicated()][0],axis=1)
        #temp = temp.drop('Address:', axis=1)
        #temp = temp.columns.drop_duplicates()
        #print(temp_info)
        #if empty_dww.shape[0] !=0 & any(empty_dww['Name'] == temp_name):
        #    driver.back()
        #    continue  join(temp_info,how='outer')
        #print(temp.columns)
    empty_district_info = pd.concat([empty_district_info,temp], axis=0, join='outer', ignore_index=True)
    empty_district_info.to_csv('../Input/tceq_audits/fort_bend_system_info.csv')
        #empty_district_info = empty_district_info.append(temp,how='outer')
        #empty_district_info =  = empty_district_info.append(temp)
        #grouped = empty_district_info.groupby(level=0)
        #empty_district_info = grouped.last()
    driver.find_element_by_css_selector('.iwud a+ a img').click()
        #doc_list = driver.find_elements_by_css_selector('.iwudcolor+ tr td')
    audit_links = driver.find_elements_by_partial_link_text('AUDIT')
    if (len(audit_links)==0):
        driver.back()
    if (len(audit_links)!=0):
        for audit in range(len(audit_links)):
            audit_links = driver.find_elements_by_partial_link_text('AUDIT')
            doc_link = audit_links[audit].get_attribute('href')
            audit_links[audit].click()   
            avars = []; avals = []
            doc_id = driver.find_element_by_css_selector(get_doc_id).text
            #print('docid')
            #print(doc_id)
            for var in driver.find_elements_by_css_selector(audit_vars_css):
                avars.append(var.text)
            for var in driver.find_elements_by_css_selector(audit_vals_css):
                avals.append(var.text)
            temp_audit = pd.DataFrame(avals).T
            temp_audit.columns = avars
            temp_audit['DOC_ID'] = doc_id
            temp_audit['SYSTEM_NAME'] = temp_name
            temp_audit['SYSTEM_ID'] = temp_id
            temp_audit['DOC_LINK'] = doc_link
                #temp_audit,index=avars,columns = [doc_id])
                #temp_audit = temp_audit.append(pd.DataFrame([id],index=['System ID'],columns=[doc_id]))
                #temp_audit = temp_audit.append(pd.DataFrame([doc_link],index=['Doc_Link'],columns=[doc_id]))
            empty_audit_info = pd.concat([empty_audit_info,temp_audit],axis=0, join='outer', ignore_index=True)
            empty_audit_info.to_csv('../Input/tceq_audits/fort_bend_audits.csv')
            time.sleep(2)
            driver.back()
        time.sleep(1)    
        driver.back()
    time.sleep(1)    
    driver.back()
    if len(temp_wd)<49 & count == len(temp_wd):
        break
    if count == 49:
        time.sleep(2)
        driver.find_element_by_css_selector(css_to_click_more).click()
        count = 0
        continue
    count = count + 1
system_list_df = pd.DataFrame({'Name': System, 'Status': Status,'ID': ID,'County': 'FORT BEND'})
#empty_dww = empty_dww.append(system_list_df)       
#harris_dww = system_list_df
system_list_df.to_csv('../Input/tceq_audits/fort_bend_base.csv')
#harris_audits = empty_audit_info
#harris_systems = empty_district_info


#while len(driver.find_element_by_css_selector(css_to_click_more))>0:
#    driver.find_element_by_css_selector(css_to_click_more).click()
# Out:
# system0
# ALIANA MANAGEMENT DISTRICT
# system1
# BELLFORT PUD
# system2
# BIG OAKS MUD
# system3
# BLUE RIDGE SOUTH MUD
# system4
# BLUE RIDGE WEST MUD
# system5
# BLUE RIDGE WEST MUD
# system6
# BOOTH RANCH MUD
# system7
# BRAZOS BEND WATER AUTHORITY
# system8
# BURLINGTON COLONY MUD
# system9
# BURNEY ROAD MUD
# system10
# CHELFORD CITY MUD
# system11
# CHERRY HILL MUD
# system12
# CHIMNEY ROCK MUD
# system13
# CINCO MUD 1
# system14
# CINCO MUD 10
# system15
# CINCO MUD 11
# system16
# CINCO MUD 12
# system17
# CINCO MUD 13
# system18
# CINCO MUD 14
# system19
# CINCO MUD 2
# system20
# CINCO MUD 3
# system21
# CINCO MUD 4
# system22
# CINCO MUD 5
# system23
# CINCO MUD 6
# system24
# CINCO MUD 7
# system25
# CINCO MUD 8
# system26
# CINCO MUD 9
# system27
# CINCO SOUTHWEST MUD 1
# system28
# CINCO SOUTHWEST MUD 2
# system29
# CINCO SOUTHWEST MUD 3
# system30
# CINCO SOUTHWEST MUD 4
# system31
# CITY OF CITIES MUD
# system32
# CITY OF CITIES MUD
# system33
# CLEAR CREEK WATERSHED REGIONAL FLOOD CONTROL DISTRICT
# system34
# COLONY BAY LID OF FORT BEND COUNTY
# system35
# CORNERSTONES MUD
# system36
# COURT ROAD MUD
# system37
# ELDRIDGE ROAD MUD
# system38
# FIRST COLONY LID
# system39
# FIRST COLONY LID 2
# system40
# FIRST COLONY MANAGEMENT DISTRICT
# system41
# FIRST COLONY MUD 1
# system42
# FIRST COLONY MUD 10
# system43
# FIRST COLONY MUD 2
# system44
# FIRST COLONY MUD 3
# system45
# FIRST COLONY MUD 4
# system46
# FIRST COLONY MUD 5
# system47
# FIRST COLONY MUD 6
# system48
# FIRST COLONY MUD 7
# system49
# FIRST COLONY MUD 8
# system50
# FIRST COLONY MUD 9
# system51
# FONDREN LAKE MUD
# system52
# FORT BEND COUNTY DRAINAGE DISTRICT
# system53
# FORT BEND COUNTY FWSD 1
# system54
# FORT BEND COUNTY FWSD 1
# system55
# FORT BEND COUNTY FWSD 2
# system56
# FORT BEND COUNTY IMPROVEMENT DISTRICT 24
# system57
# FORT BEND COUNTY LID 1
# system58
# FORT BEND COUNTY LID 10
# system59
# FORT BEND COUNTY LID 11
# system60
# FORT BEND COUNTY LID 12
# system61
# FORT BEND COUNTY LID 14
# system62
# FORT BEND COUNTY LID 15
# system63
# FORT BEND COUNTY LID 17
# system64
# FORT BEND COUNTY LID 19
# system65
# FORT BEND COUNTY LID 2
# system66
# FORT BEND COUNTY LID 20
# system67
# FORT BEND COUNTY LID 3
# system68
# FORT BEND COUNTY LID 4
# system69
# FORT BEND COUNTY LID 6
# system70
# FORT BEND COUNTY LID 7
# system71
# FORT BEND COUNTY LID 8
# system72
# FORT BEND COUNTY MMD 1
# system73
# FORT BEND COUNTY MUD 1
# system74
# FORT BEND COUNTY MUD 101
# system75
# FORT BEND COUNTY MUD 102
# system76
# FORT BEND COUNTY MUD 103
# system77
# FORT BEND COUNTY MUD 104
# system78
# FORT BEND COUNTY MUD 106
# system79
# FORT BEND COUNTY MUD 107
# system80
# FORT BEND COUNTY MUD 108
# system81
# FORT BEND COUNTY MUD 109
# system82
# FORT BEND COUNTY MUD 110
# system83
# FORT BEND COUNTY MUD 111
# system84
# FORT BEND COUNTY MUD 112
# system85
# FORT BEND COUNTY MUD 113
# system86
# FORT BEND COUNTY MUD 115
# system87
# FORT BEND COUNTY MUD 116
# system88
# FORT BEND COUNTY MUD 117
# system89
# FORT BEND COUNTY MUD 118
# system90
# FORT BEND COUNTY MUD 119
# system91
# FORT BEND COUNTY MUD 12
# system92
# FORT BEND COUNTY MUD 120
# system93
# FORT BEND COUNTY MUD 121
# system94
# FORT BEND COUNTY MUD 122
# system95
# FORT BEND COUNTY MUD 123
# system96
# FORT BEND COUNTY MUD 124
# system97
# FORT BEND COUNTY MUD 126
# system98
# FORT BEND COUNTY MUD 127
# system99
# FORT BEND COUNTY MUD 128
# system100
# FORT BEND COUNTY MUD 129
# system101
# FORT BEND COUNTY MUD 13
# system102
# FORT BEND COUNTY MUD 130
# system103
# FORT BEND COUNTY MUD 131
# system104
# FORT BEND COUNTY MUD 132
# system105
# FORT BEND COUNTY MUD 133
# system106
# FORT BEND COUNTY MUD 134
# system107
# FORT BEND COUNTY MUD 134A
# system108
# FORT BEND COUNTY MUD 134B
# system109
# FORT BEND COUNTY MUD 134C
# system110
# FORT BEND COUNTY MUD 134D
# system111
# FORT BEND COUNTY MUD 134E
# system112
# FORT BEND COUNTY MUD 136
# system113
# FORT BEND COUNTY MUD 137
# system114
# FORT BEND COUNTY MUD 138
# system115
# FORT BEND COUNTY MUD 139
# system116
# FORT BEND COUNTY MUD 140
# system117
# FORT BEND COUNTY MUD 141
# system118
# FORT BEND COUNTY MUD 142
# system119
# FORT BEND COUNTY MUD 143
# system120
# FORT BEND COUNTY MUD 144
# system121
# FORT BEND COUNTY MUD 145
# system122
# FORT BEND COUNTY MUD 146
# system123
# FORT BEND COUNTY MUD 147
# system124
# FORT BEND COUNTY MUD 148
# system125
# FORT BEND COUNTY MUD 149
# system126
# FORT BEND COUNTY MUD 150
# system127
# FORT BEND COUNTY MUD 151
# system128
# FORT BEND COUNTY MUD 152
# system129
# FORT BEND COUNTY MUD 155
# system130
# FORT BEND COUNTY MUD 156
# system131
# FORT BEND COUNTY MUD 158
# system132
# FORT BEND COUNTY MUD 159
# system133
# FORT BEND COUNTY MUD 16
# system134
# FORT BEND COUNTY MUD 161
# system135
# FORT BEND COUNTY MUD 162
# system136
# FORT BEND COUNTY MUD 163
# system137
# FORT BEND COUNTY MUD 165
# system138
# FORT BEND COUNTY MUD 166
# system139
# FORT BEND COUNTY MUD 167
# system140
# FORT BEND COUNTY MUD 168
# system141
# FORT BEND COUNTY MUD 169
# system142
# FORT BEND COUNTY MUD 170
# system143
# FORT BEND COUNTY MUD 171
# system144
# FORT BEND COUNTY MUD 172
# system145
# FORT BEND COUNTY MUD 173
# system146
# FORT BEND COUNTY MUD 176
# system147
# FORT BEND COUNTY MUD 177
# system148
# FORT BEND COUNTY MUD 182
# system149
# FORT BEND COUNTY MUD 183
# system150
# FORT BEND COUNTY MUD 184
# system151
# FORT BEND COUNTY MUD 185
# system152
# FORT BEND COUNTY MUD 187
# system153
# FORT BEND COUNTY MUD 188
# system154
# FORT BEND COUNTY MUD 189
# system155
# FORT BEND COUNTY MUD 19
# system156
# FORT BEND COUNTY MUD 190
# system157
# FORT BEND COUNTY MUD 191
# system158
# FORT BEND COUNTY MUD 192
# system159
# FORT BEND COUNTY MUD 194
# system160
# FORT BEND COUNTY MUD 195
# system161
# FORT BEND COUNTY MUD 198
# system162
# FORT BEND COUNTY MUD 199
# system163
# FORT BEND COUNTY MUD 2
# system164
# FORT BEND COUNTY MUD 20
# system165
# FORT BEND COUNTY MUD 200
# system166
# FORT BEND COUNTY MUD 201
# system167
# FORT BEND COUNTY MUD 202
# system168
# FORT BEND COUNTY MUD 203
# system169
# FORT BEND COUNTY MUD 204
# system170
# FORT BEND COUNTY MUD 206
# system171
# FORT BEND COUNTY MUD 207
# system172
# FORT BEND COUNTY MUD 208
# system173
# FORT BEND COUNTY MUD 209
# system174
# FORT BEND COUNTY MUD 21
# system175
# FORT BEND COUNTY MUD 210
# system176
# FORT BEND COUNTY MUD 211
# system177
# FORT BEND COUNTY MUD 212
# system178
# FORT BEND COUNTY MUD 213
# system179
# FORT BEND COUNTY MUD 214
# system180
# FORT BEND COUNTY MUD 215
# system181
# FORT BEND COUNTY MUD 216
# system182
# FORT BEND COUNTY MUD 218
# system183
# FORT BEND COUNTY MUD 219
# system184
# FORT BEND COUNTY MUD 23
# system185
# FORT BEND COUNTY MUD 24
# system186
# FORT BEND COUNTY MUD 25
# system187
# FORT BEND COUNTY MUD 26
# system188
# FORT BEND COUNTY MUD 27
# system189
# FORT BEND COUNTY MUD 28
# system190
# FORT BEND COUNTY MUD 30
# system191
# FORT BEND COUNTY MUD 31
# system192
# FORT BEND COUNTY MUD 34
# system193
# FORT BEND COUNTY MUD 35
# system194
# FORT BEND COUNTY MUD 36
# system195
# FORT BEND COUNTY MUD 37
# system196
# FORT BEND COUNTY MUD 41
# system197
# FORT BEND COUNTY MUD 42
# system198
# FORT BEND COUNTY MUD 44
# system199
# FORT BEND COUNTY MUD 45
# system200
# FORT BEND COUNTY MUD 46
# system201
# FORT BEND COUNTY MUD 47
# system202
# FORT BEND COUNTY MUD 48
# system203
# FORT BEND COUNTY MUD 49
# system204
# FORT BEND COUNTY MUD 5
# system205
# FORT BEND COUNTY MUD 50
# system206
# FORT BEND COUNTY MUD 51
# system207
# FORT BEND COUNTY MUD 52
# system208
# FORT BEND COUNTY MUD 53
# system209
# FORT BEND COUNTY MUD 54
# system210
# FORT BEND COUNTY MUD 55
# system211
# FORT BEND COUNTY MUD 56
# system212
# FORT BEND COUNTY MUD 57
# system213
# FORT BEND COUNTY MUD 58
# system214
# FORT BEND COUNTY MUD 59
# system215
# FORT BEND COUNTY MUD 60
# system216
# FORT BEND COUNTY MUD 63
# system217
# FORT BEND COUNTY MUD 65
# system218
# FORT BEND COUNTY MUD 66
# system219
# FORT BEND COUNTY MUD 67
# system220
# FORT BEND COUNTY MUD 68
# system221
# FORT BEND COUNTY MUD 69
# system222
# FORT BEND COUNTY MUD 73
# system223
# FORT BEND COUNTY MUD 74
# system224
# FORT BEND COUNTY MUD 77
# system225
# FORT BEND COUNTY MUD 79
# system226
# FORT BEND COUNTY MUD 81
# system227
# FORT BEND COUNTY MUD 9
# system228
# FORT BEND COUNTY MUD 92
# system229
# FORT BEND COUNTY MUD 93
# system230
# FORT BEND COUNTY MUD 94
# system231
# FORT BEND COUNTY WATER SUPPLY DISTRICT
# system232
# FORT BEND COUNTY WCID 1
# system233
# FORT BEND COUNTY WCID 10
# system234
# FORT BEND COUNTY WCID 2
# system235
# FORT BEND COUNTY WCID 3
# system236
# FORT BEND COUNTY WCID 3
# system237
# FORT BEND COUNTY WCID 3
# system238
# FORT BEND COUNTY WCID 4
# system239
# FORT BEND COUNTY WCID 4
# system240
# FORT BEND COUNTY WCID 8
# system241
# FORT BEND SUBSIDENCE DISTRICT
# system242
# FORT BEND-WALLER COUNTIES MUD 2
# system243
# FORT BEND-WALLER COUNTIES MUD 3
# system244
# FULSHEAR MUD 1
# system245
# FULSHEAR MUD 2
# system246
# FULSHEAR MUD 3A
# system247
# FULSHEAR MUD 3B
# system248
# FULSHEAR MUD 4
# system249
# FULSHEAR MUD 5
# system250
# FULSHEAR MUD 6
# system251
# FULSHEAR PARKWAY IMPROVEMENT DISTRICT
# system252
# FULSHEAR TOWN CENTER MANAGEMENT DISTRICT
# system253
# GRAND LAKES MUD 1
# system254
# GRAND LAKES MUD 2
# system255
# GRAND LAKES MUD 4
# system256
# GRAND LAKES WCID
# system257
# GRAND MISSION MUD 1
# system258
# GRAND MISSION MUD 2
# system259
# GREEN RIDGE MUD
# system260
# HARRIS COUNTY WCID 111
# system261
# HARRIS COUNTY WCID 111
# system262
# HARRIS FORT BEND COUNTIES MUD 1
# system263
# HARRIS FORT BEND COUNTIES MUD 3
# system264
# HARRIS FORT BEND COUNTIES MUD 5
# system265
# IMPERIAL REDEVELOPMENT DISTRICT
# system266
# KATY MANAGEMENT DISTRICT 1
# system267
# KENDLETON IMPROVEMENT DISTRICT
# system268
# KINGSBRIDGE MUD
# system269
# MAYFAIR PARK MUD
# system270
# MCHARD ROAD MUD
# system271
# MEADOWCREEK MUD
# system272
# MEADOWS MUD
# system273
# MEADOWS MUD
# system274
# MISSION BEND MUD 1
# system275
# MISSOURI CITY MANAGEMENT DISTRICT 1
# system276
# MISSOURI CITY MANAGEMENT DISTRICT 2
# system277
# NORTH FORT BEND COUNTY IMPROVEMENT DISTRICT 1
# system278
# NORTH FORT BEND WATER AUTHORITY
# system279
# NORTH MISSION GLEN MUD
# system280
# PALMER PLANTATION MUD 1
# system281
# PALMER PLANTATION MUD 2
# system282
# PECAN GROVE MUD
# system283
# PECAN GROVE MUD 1
# system284
# PLANTATION MUD
# system285
# POST OAK ROAD MUD
# system286
# POST OAK ROAD MUD
# system287
# QUAIL VALLEY UTILITY DISTRICT
# system288
# QUAIL VALLEY UTILITY DISTRICT
# system289
# RENN ROAD MUD
# system290
# RIDGEMONT MUD
# system291
# ROSE RICH MUD
# system292
# SAN JACINTO RIVER AUTHORITY
# system293
# SEABOURNE CREEK PUD
# system294
# SIENNA PLANTATION FWSD
# system295
# SIENNA PLANTATION LID
# system296
# SIENNA PLANTATION MANAGEMENT DISTRICT
# system297
# SIENNA PLANTATION MUD 1
# system298
# SIENNA PLANTATION MUD 1
# system299
# SIENNA PLANTATION MUD 10
# system300
# SIENNA PLANTATION MUD 11
# system301
# SIENNA PLANTATION MUD 12
# system302
# SIENNA PLANTATION MUD 13
# system303
# SIENNA PLANTATION MUD 2
# system304
# SIENNA PLANTATION MUD 3
# system305
# SIENNA PLANTATION MUD 4
# system306
# SIENNA PLANTATION MUD 5
# system307
# SIENNA PLANTATION MUD 6
# system308
# SIENNA PLANTATION MUD 7
# system309
# SIENNA PLANTATION MUD 8
# system310
# SIENNA PLANTATION MUD 9
# system311
# SIMONTON MANAGEMENT DISTRICT 1
# system312
# SOUTH MISSION GLEN MUD
# system313
# STAFFORDSHIRE MUD
# system314
# THUNDERBIRD UTILITY DISTRICT
# system315
# TWINWOOD MUD 1
# system316
# VIA RANCH MUD 1
# system317
# VIA RANCH MUD 2
# system318
# VIA RANCH MUD 3
# system319
# VIA RANCH MUD 4
# system320
# VIA RANCH WCID 1
# system321
# VILLAGE AT KATY DEVELOPMENT DISTRICT
# system322
# WEST FORT BEND MANAGEMENT DISTRICT
# system323
# WEST FORT BEND WATER AUTHORITY
# system324
# WEST HARRIS COUNTY RWA
# system325
# WEST KEEGANS BAYOU IMPROVEMENT DISTRICT
# system326
# WILLIAMS RANCH MUD 1
# system327
# WILLOW FORK DRAINAGE DISTRICT
# system328
# WILLOW POINT MUD
# system329
# WILLOWISP MUD
# system330
# WOODCREEK RESERVE MUD
# system331
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-eb2d418234fc> in <module>()
#      46     temp_status = driver.find_elements_by_css_selector(css_find_status)
#      47     temp_number = driver.find_elements_by_css_selector(css_find_number)
# ---> 48     System.append(temp_wd[count].text)
#      49     Status.append(temp_status[count].text)
#      50     ID.append(temp_number[count].text)
#
# IndexError: list index out of range

# %%
system_list_df = pd.DataFrame({'Name': System, 'Status': Status,'ID': ID,'County': 'FORT BEND'})
#empty_dww = empty_dww.append(system_list_df)       
#harris_dww = system_list_df
system_list_df.to_csv('../Input/tceq_audits/fort_bend_base.csv')

# %%
# Out:
# (1293, 31)
